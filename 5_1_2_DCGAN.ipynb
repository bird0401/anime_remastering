# %% [markdown]
# <a href="https://colab.research.google.com/github/bird0401/anime_remastering/blob/main/5_1_2_DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5.1-2 DCGANの作成
#
# - 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。

# %% [markdown]
# # 5.1 学習目標
#
# 1.	Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# 2.	Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# 3.	GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# 4.	DCGANのネットワークを実装できるようになる

# %% [markdown]
# # 5.2 学習目標
#
# 1.	GANの損失関数の形を理解する
# 2.	DCGANを実装し、手書き数字画像が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd 
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/pytorch_advanced-master/5_gan_generation/data .

# %%
 # Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # 転置畳み込みの例

# %%
input = torch.tensor([[[[1., 1.], [2., 2.]]]])
print("入力データ")
print(input)
print("-----")

print("通常の畳み込み")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight.data[0, 0, 0, 0] = 1
m.weight.data[0, 0, 0, 1] = 2
m.weight.data[0, 0, 1, 0] = 3
m.weight.data[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))

print("-----")
print("転置畳み込み")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight.data[0, 0, 0, 0] = 1
m.weight.data[0, 0, 0, 1] = 2
m.weight.data[0, 0, 1, 0] = 3
m.weight.data[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))
# Out:
# 入力データ
# tensor([[[[1., 1.],
#           [2., 2.]]]])
# -----
# 通常の畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], requires_grad=True)
# 出力
# tensor([[[[17.]]]], grad_fn=<ConvolutionBackward0>)
# -----
# 転置畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], requires_grad=True)
# 出力
# tensor([[[[ 1.,  3.,  2.],
#           [ 5., 13.,  8.],
#           [ 6., 14.,  8.]]]], grad_fn=<ConvolutionBackward0>)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5014]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# # 6.2へ

# %% [markdown]
# # GANの損失関数

# %%
# # Dの誤差関数のイメージ実装
# # maximize log(D(x)) + log(1 - D(G(z)))


# # ※ xが未定義なので動作はエラーになります
# #---------------


# # 正解ラベルを作成
# mini_batch_size = 2
# label_real = torch.full((mini_batch_size,), 1)

# # 偽ラベルを作成
# label_fake = torch.full((mini_batch_size,), 0)

# # 誤差関数を定義
# criterion = nn.BCEWithLogitsLoss(reduction='mean')

# # 真の画像を判定
# d_out_real = D(x)

# # 偽の画像を生成して判定
# input_z = torch.randn(mini_batch_size, 20)
# input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
# fake_images = G(input_z)
# d_out_fake = D(fake_images)

# # 誤差を計算
# d_loss_real = criterion(d_out_real.view(-1), label_real)
# d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
# d_loss = d_loss_real + d_loss_fake

# %%
# # Gの誤差関数のイメージ実装
# # maximize log(D(G(z)))


# # ※ xが未定義なので動作はエラーになります
# #---------------


# # 偽の画像を生成して判定
# input_z = torch.randn(mini_batch_size, 20)
# input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
# fake_images = G(input_z)
# d_out_fake = D(fake_images)

# # 誤差を計算
# g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            # issue #186より不要なのでコメントアウト
            # if imges.size()[0] == 1:
            #     continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # # 誤差を計算
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            # d_loss = d_loss_real + d_loss_fake

            label_real = label_real.type_as(d_out_real.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake
            
            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 200
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/200
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.1433
# timer:  1.0855 sec.
# -------------
# Epoch 1/200
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0338 ||Epoch_G_Loss:0.3376
# timer:  0.4576 sec.
# -------------
# Epoch 2/200
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.0029 ||Epoch_G_Loss:0.5462
# timer:  0.4655 sec.
# -------------
# Epoch 3/200
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.2862 ||Epoch_G_Loss:0.5337
# timer:  0.4649 sec.
# -------------
# Epoch 4/200
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.0870
# timer:  0.4594 sec.
# -------------
# Epoch 5/200
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0760 ||Epoch_G_Loss:0.1898
# timer:  0.4523 sec.
# -------------
# Epoch 6/200
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0098 ||Epoch_G_Loss:0.3492
# timer:  0.4650 sec.
# -------------
# Epoch 7/200
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.2744 ||Epoch_G_Loss:0.4257
# timer:  0.4554 sec.
# -------------
# Epoch 8/200
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0203 ||Epoch_G_Loss:0.2453
# timer:  0.4630 sec.
# -------------
# Epoch 9/200
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.3133
# timer:  0.4541 sec.
# -------------
# Epoch 10/200
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.2255 ||Epoch_G_Loss:0.3195
# timer:  0.4562 sec.
# -------------
# Epoch 11/200
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0194 ||Epoch_G_Loss:0.2504
# timer:  0.4572 sec.
# -------------
# Epoch 12/200
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.1515 ||Epoch_G_Loss:0.2531
# timer:  0.4602 sec.
# -------------
# Epoch 13/200
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0187 ||Epoch_G_Loss:0.3254
# timer:  0.4561 sec.
# -------------
# Epoch 14/200
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.1250 ||Epoch_G_Loss:0.2569
# timer:  0.4571 sec.
# -------------
# Epoch 15/200
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.2949
# timer:  0.4678 sec.
# -------------
# Epoch 16/200
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.1366 ||Epoch_G_Loss:0.2708
# timer:  0.4636 sec.
# -------------
# Epoch 17/200
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0931 ||Epoch_G_Loss:0.2831
# timer:  0.4537 sec.
# -------------
# Epoch 18/200
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.2890
# timer:  0.4588 sec.
# -------------
# Epoch 19/200
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.1226 ||Epoch_G_Loss:0.2730
# timer:  0.4541 sec.
# -------------
# Epoch 20/200
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1102 ||Epoch_G_Loss:0.2991
# timer:  0.4531 sec.
# -------------
# Epoch 21/200
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0180 ||Epoch_G_Loss:0.2967
# timer:  0.4517 sec.
# -------------
# Epoch 22/200
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.3551
# timer:  0.4579 sec.
# -------------
# Epoch 23/200
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0212 ||Epoch_G_Loss:0.2688
# timer:  0.4563 sec.
# -------------
# Epoch 24/200
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1403 ||Epoch_G_Loss:0.2947
# timer:  0.4599 sec.
# -------------
# Epoch 25/200
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.1280 ||Epoch_G_Loss:0.2675
# timer:  0.4562 sec.
# -------------
# Epoch 26/200
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1414 ||Epoch_G_Loss:0.1904
# timer:  0.4626 sec.
# -------------
# Epoch 27/200
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1620
# timer:  0.4552 sec.
# -------------
# Epoch 28/200
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.1772
# timer:  0.4544 sec.
# -------------
# Epoch 29/200
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1569 ||Epoch_G_Loss:0.2022
# timer:  0.4590 sec.
# -------------
# Epoch 30/200
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0846 ||Epoch_G_Loss:0.1800
# timer:  0.4607 sec.
# -------------
# Epoch 31/200
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1347
# timer:  0.4643 sec.
# -------------
# Epoch 32/200
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.1701
# timer:  0.4673 sec.
# -------------
# Epoch 33/200
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1411
# timer:  0.4585 sec.
# -------------
# Epoch 34/200
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1028 ||Epoch_G_Loss:0.1783
# timer:  0.4599 sec.
# -------------
# Epoch 35/200
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1029 ||Epoch_G_Loss:0.1684
# timer:  0.5883 sec.
# -------------
# Epoch 36/200
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1259 ||Epoch_G_Loss:0.1364
# timer:  0.4603 sec.
# -------------
# Epoch 37/200
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0910 ||Epoch_G_Loss:0.1758
# timer:  0.6012 sec.
# -------------
# Epoch 38/200
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1797
# timer:  0.4687 sec.
# -------------
# Epoch 39/200
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1127 ||Epoch_G_Loss:0.1631
# timer:  0.4620 sec.
# -------------
# Epoch 40/200
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.1635
# timer:  0.4611 sec.
# -------------
# Epoch 41/200
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1647
# timer:  0.4656 sec.
# -------------
# Epoch 42/200
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1298 ||Epoch_G_Loss:0.1763
# timer:  0.4550 sec.
# -------------
# Epoch 43/200
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1554
# timer:  0.4529 sec.
# -------------
# Epoch 44/200
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1411 ||Epoch_G_Loss:0.1291
# timer:  0.4496 sec.
# -------------
# Epoch 45/200
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1113 ||Epoch_G_Loss:0.1515
# timer:  0.4651 sec.
# -------------
# Epoch 46/200
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1401
# timer:  0.4593 sec.
# -------------
# Epoch 47/200
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.1324
# timer:  0.4558 sec.
# -------------
# Epoch 48/200
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1244 ||Epoch_G_Loss:0.1273
# timer:  0.4658 sec.
# -------------
# Epoch 49/200
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.1341
# timer:  0.4668 sec.
# -------------
# Epoch 50/200
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1112 ||Epoch_G_Loss:0.1132
# timer:  0.4650 sec.
# -------------
# Epoch 51/200
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.1367
# timer:  0.4562 sec.
# -------------
# Epoch 52/200
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1174 ||Epoch_G_Loss:0.1246
# timer:  0.4574 sec.
# -------------
# Epoch 53/200
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1275 ||Epoch_G_Loss:0.1131
# timer:  0.4551 sec.
# -------------
# Epoch 54/200
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1313 ||Epoch_G_Loss:0.1319
# timer:  0.4637 sec.
# -------------
# Epoch 55/200
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.1155
# timer:  0.4632 sec.
# -------------
# Epoch 56/200
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1089 ||Epoch_G_Loss:0.1458
# timer:  0.4622 sec.
# -------------
# Epoch 57/200
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1279
# timer:  0.4642 sec.
# -------------
# Epoch 58/200
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1273 ||Epoch_G_Loss:0.1575
# timer:  0.4564 sec.
# -------------
# Epoch 59/200
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0997 ||Epoch_G_Loss:0.1384
# timer:  0.4588 sec.
# -------------
# Epoch 60/200
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1542
# timer:  0.4531 sec.
# -------------
# Epoch 61/200
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1023 ||Epoch_G_Loss:0.1411
# timer:  0.4541 sec.
# -------------
# Epoch 62/200
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1017 ||Epoch_G_Loss:0.1634
# timer:  0.4605 sec.
# -------------
# Epoch 63/200
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0991 ||Epoch_G_Loss:0.1581
# timer:  0.4644 sec.
# -------------
# Epoch 64/200
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1604
# timer:  0.4617 sec.
# -------------
# Epoch 65/200
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0982 ||Epoch_G_Loss:0.1772
# timer:  0.4762 sec.
# -------------
# Epoch 66/200
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0918 ||Epoch_G_Loss:0.1591
# timer:  0.4610 sec.
# -------------
# Epoch 67/200
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0977 ||Epoch_G_Loss:0.1619
# timer:  0.4574 sec.
# -------------
# Epoch 68/200
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.2126
# timer:  0.4649 sec.
# -------------
# Epoch 69/200
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1369 ||Epoch_G_Loss:0.1403
# timer:  0.4664 sec.
# -------------
# Epoch 70/200
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0743 ||Epoch_G_Loss:0.1765
# timer:  0.4788 sec.
# -------------
# Epoch 71/200
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1020 ||Epoch_G_Loss:0.1776
# timer:  0.4713 sec.
# -------------
# Epoch 72/200
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.1940
# timer:  0.4779 sec.
# -------------
# Epoch 73/200
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.1702
# timer:  0.4636 sec.
# -------------
# Epoch 74/200
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1985
# timer:  0.4648 sec.
# -------------
# Epoch 75/200
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.1844
# timer:  0.4625 sec.
# -------------
# Epoch 76/200
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1902
# timer:  0.4656 sec.
# -------------
# Epoch 77/200
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0832 ||Epoch_G_Loss:0.1803
# timer:  0.4579 sec.
# -------------
# Epoch 78/200
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0870 ||Epoch_G_Loss:0.1972
# timer:  0.4707 sec.
# -------------
# Epoch 79/200
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.1687
# timer:  0.4645 sec.
# -------------
# Epoch 80/200
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1956
# timer:  0.4733 sec.
# -------------
# Epoch 81/200
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.1841
# timer:  0.4602 sec.
# -------------
# Epoch 82/200
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.1849
# timer:  0.4754 sec.
# -------------
# Epoch 83/200
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1728
# timer:  0.4669 sec.
# -------------
# Epoch 84/200
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2153
# timer:  0.4680 sec.
# -------------
# Epoch 85/200
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.1729
# timer:  0.4646 sec.
# -------------
# Epoch 86/200
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.2130
# timer:  0.4663 sec.
# -------------
# Epoch 87/200
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2048
# timer:  0.4694 sec.
# -------------
# Epoch 88/200
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1095 ||Epoch_G_Loss:0.1873
# timer:  0.4667 sec.
# -------------
# Epoch 89/200
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1923
# timer:  0.4695 sec.
# -------------
# Epoch 90/200
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.2017
# timer:  0.4651 sec.
# -------------
# Epoch 91/200
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0971 ||Epoch_G_Loss:0.2108
# timer:  0.4729 sec.
# -------------
# Epoch 92/200
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0711 ||Epoch_G_Loss:0.1745
# timer:  0.4679 sec.
# -------------
# Epoch 93/200
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.2096
# timer:  0.4684 sec.
# -------------
# Epoch 94/200
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0654 ||Epoch_G_Loss:0.1945
# timer:  0.4677 sec.
# -------------
# Epoch 95/200
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.1159 ||Epoch_G_Loss:0.2253
# timer:  0.4634 sec.
# -------------
# Epoch 96/200
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.1971
# timer:  0.4719 sec.
# -------------
# Epoch 97/200
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.2093
# timer:  0.4622 sec.
# -------------
# Epoch 98/200
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0617 ||Epoch_G_Loss:0.2369
# timer:  0.4781 sec.
# -------------
# Epoch 99/200
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1753
# timer:  0.4664 sec.
# -------------
# Epoch 100/200
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.2159
# timer:  0.4688 sec.
# -------------
# Epoch 101/200
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0721 ||Epoch_G_Loss:0.2002
# timer:  0.4650 sec.
# -------------
# Epoch 102/200
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0775 ||Epoch_G_Loss:0.2119
# timer:  0.4623 sec.
# -------------
# Epoch 103/200
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0797 ||Epoch_G_Loss:0.2105
# timer:  0.4621 sec.
# -------------
# Epoch 104/200
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0603 ||Epoch_G_Loss:0.2294
# timer:  0.4602 sec.
# -------------
# Epoch 105/200
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0867 ||Epoch_G_Loss:0.1961
# timer:  0.4647 sec.
# -------------
# Epoch 106/200
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0705 ||Epoch_G_Loss:0.2357
# timer:  0.4645 sec.
# -------------
# Epoch 107/200
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.2138
# timer:  0.4665 sec.
# -------------
# Epoch 108/200
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.2225
# timer:  0.4652 sec.
# -------------
# Epoch 109/200
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.2320
# timer:  0.4594 sec.
# -------------
# Epoch 110/200
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2122
# timer:  0.4673 sec.
# -------------
# Epoch 111/200
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.2287
# timer:  0.4696 sec.
# -------------
# Epoch 112/200
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0819 ||Epoch_G_Loss:0.2574
# timer:  0.4654 sec.
# -------------
# Epoch 113/200
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0690 ||Epoch_G_Loss:0.2224
# timer:  0.4701 sec.
# -------------
# Epoch 114/200
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2337
# timer:  0.4598 sec.
# -------------
# Epoch 115/200
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0743 ||Epoch_G_Loss:0.2277
# timer:  0.4662 sec.
# -------------
# Epoch 116/200
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.2348
# timer:  0.4612 sec.
# -------------
# Epoch 117/200
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0755 ||Epoch_G_Loss:0.2155
# timer:  0.4690 sec.
# -------------
# Epoch 118/200
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.2519
# timer:  0.4733 sec.
# -------------
# Epoch 119/200
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.2254
# timer:  0.4623 sec.
# -------------
# Epoch 120/200
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0741 ||Epoch_G_Loss:0.2488
# timer:  0.4728 sec.
# -------------
# Epoch 121/200
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0743 ||Epoch_G_Loss:0.2814
# timer:  0.4687 sec.
# -------------
# Epoch 122/200
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.2112
# timer:  0.4682 sec.
# -------------
# Epoch 123/200
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0676 ||Epoch_G_Loss:0.2344
# timer:  0.4588 sec.
# -------------
# Epoch 124/200
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0538 ||Epoch_G_Loss:0.2561
# timer:  0.4531 sec.
# -------------
# Epoch 125/200
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.2881
# timer:  0.4560 sec.
# -------------
# Epoch 126/200
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.2201
# timer:  0.4637 sec.
# -------------
# Epoch 127/200
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.2645
# timer:  0.4585 sec.
# -------------
# Epoch 128/200
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0676 ||Epoch_G_Loss:0.2271
# timer:  0.4712 sec.
# -------------
# Epoch 129/200
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0622 ||Epoch_G_Loss:0.2577
# timer:  0.4488 sec.
# -------------
# Epoch 130/200
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0664 ||Epoch_G_Loss:0.2411
# timer:  0.4592 sec.
# -------------
# Epoch 131/200
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.2768
# timer:  0.4619 sec.
# -------------
# Epoch 132/200
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0648 ||Epoch_G_Loss:0.2563
# timer:  0.4565 sec.
# -------------
# Epoch 133/200
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0527 ||Epoch_G_Loss:0.2970
# timer:  0.4581 sec.
# -------------
# Epoch 134/200
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2648
# timer:  0.4583 sec.
# -------------
# Epoch 135/200
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0648 ||Epoch_G_Loss:0.2756
# timer:  0.4596 sec.
# -------------
# Epoch 136/200
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.2781
# timer:  0.4596 sec.
# -------------
# Epoch 137/200
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0764 ||Epoch_G_Loss:0.2761
# timer:  0.4660 sec.
# -------------
# Epoch 138/200
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0543 ||Epoch_G_Loss:0.2791
# timer:  0.4600 sec.
# -------------
# Epoch 139/200
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0481 ||Epoch_G_Loss:0.3288
# timer:  0.4643 sec.
# -------------
# Epoch 140/200
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.2389
# timer:  0.4655 sec.
# -------------
# Epoch 141/200
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0348 ||Epoch_G_Loss:0.2977
# timer:  0.4707 sec.
# -------------
# Epoch 142/200
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.2911
# timer:  0.4591 sec.
# -------------
# Epoch 143/200
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0415 ||Epoch_G_Loss:0.2909
# timer:  0.4675 sec.
# -------------
# Epoch 144/200
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.3033
# timer:  0.4685 sec.
# -------------
# Epoch 145/200
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.2868
# timer:  0.4695 sec.
# -------------
# Epoch 146/200
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.3099
# timer:  0.4618 sec.
# -------------
# Epoch 147/200
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0417 ||Epoch_G_Loss:0.2966
# timer:  0.4606 sec.
# -------------
# Epoch 148/200
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.3308
# timer:  0.4628 sec.
# -------------
# Epoch 149/200
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0590 ||Epoch_G_Loss:0.2854
# timer:  0.4570 sec.
# -------------
# Epoch 150/200
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0517 ||Epoch_G_Loss:0.3237
# timer:  0.4655 sec.
# -------------
# Epoch 151/200
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0391 ||Epoch_G_Loss:0.2715
# timer:  0.4739 sec.
# -------------
# Epoch 152/200
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.3129
# timer:  0.4656 sec.
# -------------
# Epoch 153/200
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0404 ||Epoch_G_Loss:0.2832
# timer:  0.4727 sec.
# -------------
# Epoch 154/200
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.3202
# timer:  0.4640 sec.
# -------------
# Epoch 155/200
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0341 ||Epoch_G_Loss:0.2915
# timer:  0.4692 sec.
# -------------
# Epoch 156/200
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.3617
# timer:  0.4601 sec.
# -------------
# Epoch 157/200
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0579 ||Epoch_G_Loss:0.2954
# timer:  0.4614 sec.
# -------------
# Epoch 158/200
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0594 ||Epoch_G_Loss:0.3193
# timer:  0.4659 sec.
# -------------
# Epoch 159/200
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.3425
# timer:  0.4709 sec.
# -------------
# Epoch 160/200
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0443 ||Epoch_G_Loss:0.2974
# timer:  0.4619 sec.
# -------------
# Epoch 161/200
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.3157
# timer:  0.4636 sec.
# -------------
# Epoch 162/200
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.3290
# timer:  0.4559 sec.
# -------------
# Epoch 163/200
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0662 ||Epoch_G_Loss:0.3289
# timer:  0.4657 sec.
# -------------
# Epoch 164/200
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0338 ||Epoch_G_Loss:0.3346
# timer:  0.4695 sec.
# -------------
# Epoch 165/200
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.3437
# timer:  0.4692 sec.
# -------------
# Epoch 166/200
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0461 ||Epoch_G_Loss:0.3271
# timer:  0.4724 sec.
# -------------
# Epoch 167/200
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0465 ||Epoch_G_Loss:0.3562
# timer:  0.4694 sec.
# -------------
# Epoch 168/200
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.3525
# timer:  0.4661 sec.
# -------------
# Epoch 169/200
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.2953
# timer:  0.4624 sec.
# -------------
# Epoch 170/200
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.3549
# timer:  0.4654 sec.
# -------------
# Epoch 171/200
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0310 ||Epoch_G_Loss:0.3310
# timer:  0.4647 sec.
# -------------
# Epoch 172/200
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.3868
# timer:  0.4643 sec.
# -------------
# Epoch 173/200
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0430 ||Epoch_G_Loss:0.3167
# timer:  0.4736 sec.
# -------------
# Epoch 174/200
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0375 ||Epoch_G_Loss:0.3728
# timer:  0.4658 sec.
# -------------
# Epoch 175/200
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0494 ||Epoch_G_Loss:0.3255
# timer:  0.4683 sec.
# -------------
# Epoch 176/200
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.3687
# timer:  0.4607 sec.
# -------------
# Epoch 177/200
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0274 ||Epoch_G_Loss:0.3815
# timer:  0.4656 sec.
# -------------
# Epoch 178/200
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.3289
# timer:  0.4620 sec.
# -------------
# Epoch 179/200
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.3622
# timer:  0.4635 sec.
# -------------
# Epoch 180/200
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0598 ||Epoch_G_Loss:0.4000
# timer:  0.4580 sec.
# -------------
# Epoch 181/200
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0354 ||Epoch_G_Loss:0.3366
# timer:  0.4626 sec.
# -------------
# Epoch 182/200
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0368 ||Epoch_G_Loss:0.3719
# timer:  0.4600 sec.
# -------------
# Epoch 183/200
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.3918
# timer:  0.4576 sec.
# -------------
# Epoch 184/200
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0259 ||Epoch_G_Loss:0.3751
# timer:  0.4568 sec.
# -------------
# Epoch 185/200
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.3989
# timer:  0.4539 sec.
# -------------
# Epoch 186/200
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.3982
# timer:  0.4548 sec.
# -------------
# Epoch 187/200
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0530 ||Epoch_G_Loss:0.3675
# timer:  0.4596 sec.
# -------------
# Epoch 188/200
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0229 ||Epoch_G_Loss:0.3822
# timer:  0.4664 sec.
# -------------
# Epoch 189/200
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.3989
# timer:  0.4589 sec.
# -------------
# Epoch 190/200
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0388 ||Epoch_G_Loss:0.3702
# timer:  0.4579 sec.
# -------------
# Epoch 191/200
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0219 ||Epoch_G_Loss:0.4342
# timer:  0.4543 sec.
# -------------
# Epoch 192/200
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0685 ||Epoch_G_Loss:0.4322
# timer:  0.4599 sec.
# -------------
# Epoch 193/200
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0254 ||Epoch_G_Loss:0.3700
# timer:  0.4583 sec.
# -------------
# Epoch 194/200
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0319 ||Epoch_G_Loss:0.4374
# timer:  0.4566 sec.
# -------------
# Epoch 195/200
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0408 ||Epoch_G_Loss:0.3740
# timer:  0.4719 sec.
# -------------
# Epoch 196/200
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0247 ||Epoch_G_Loss:0.4234
# timer:  0.4550 sec.
# -------------
# Epoch 197/200
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0436 ||Epoch_G_Loss:0.4147
# timer:  0.4674 sec.
# -------------
# Epoch 198/200
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0316 ||Epoch_G_Loss:0.4136
# timer:  0.4582 sec.
# -------------
# Epoch 199/200
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.4039
# timer:  0.4665 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# 以上
