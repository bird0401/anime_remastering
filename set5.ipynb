# %% [markdown]
# <a href="https://colab.research.google.com/github/bird0401/anime_remastering/blob/main/set5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install super-image
# !pip install datasets

# %%
from datasets import load_dataset
# from super_image import EdsrModel
from super_image.data import EvalDataset, EvalMetrics

# %%
dataset = load_dataset('eugenesiow/Set5', 'bicubic_x2', split='validation')
dataset
# Out:
# Reusing dataset set5 (/root/.cache/huggingface/datasets/eugenesiow___set5/bicubic_x2/1.0.0/e0c6fb24ad5c097bcc602e43704e322b619ce96a3bb212e085cabdafae69727f)
# Dataset({
#     features: ['hr', 'lr'],
#     num_rows: 5
# })

# %%
import cv2
import matplotlib.pyplot as plt

# %%
dataset['hr'][0]
# Out:
# '/root/.cache/huggingface/datasets/downloads/extracted/0ddd43918bcf04db71a20394d1da24153293e6baf29f66ad0dbece31bc89e0f8/Set5_HR/baby.png'

# %%
len(dataset['hr'])
# Out:
# 5

# %%
fig = plt.figure()

for i in range(5):
  img=cv2.imread(dataset['hr'][i])
  img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  ax = fig.add_subplot(2, 3, i+1)
  plt.imshow(img)

# %%
fig = plt.figure()

for i in range(5):
  img=cv2.imread(dataset['lr'][i])
  img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  ax = fig.add_subplot(2, 3, i+1)
  plt.imshow(img)

# %%
# eval_dataset = EvalDataset(dataset)
# model = EdsrModel.from_pretrained('eugenesiow/edsr-base', scale=2)
# EvalMetrics().evaluate(model, eval_dataset)
